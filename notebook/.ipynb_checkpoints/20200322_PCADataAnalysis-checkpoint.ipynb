# %% [markdown]
# # PCA Analysis

# %%
## Importing all the package
## Especially the package dataextract
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.ensemble import IsolationForest
import sys
sys.path.insert(1, '../src')
from dataextract import data_pca_exploration

# %%
PATH_DATA='../data/'

# %% [markdown]
# ## Get the data

# %%
df_raw=pd.read_csv(PATH_DATA+'winequality-red.csv')

# %%
df_raw.sample(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 524             9.2             0.430         0.49             2.4      0.086
# 837             6.7             0.280         0.28             2.4      0.012
# 1336            6.0             0.500         0.00             1.4      0.057
# 102             8.1             0.545         0.18             1.9      0.080
# 779             7.1             0.520         0.03             2.6      0.076
# 222             6.8             0.610         0.04             1.5      0.057
# 700            10.6             1.020         0.43             2.9      0.076
# 526             7.3             0.365         0.49             2.5      0.088
# 1202            8.6             0.420         0.39             1.8      0.068
# 933             7.4             0.610         0.01             2.0      0.074
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 524                  23.0                 116.0  0.99760  3.23       0.64
# 837                  36.0                 100.0  0.99064  3.26       0.39
# 1336                 15.0                  26.0  0.99448  3.36       0.45
# 102                  13.0                  35.0  0.99720  3.30       0.59
# 779                  21.0                  92.0  0.99745  3.50       0.60
# 222                   5.0                  10.0  0.99525  3.42       0.60
# 700                  26.0                  88.0  0.99840  3.08       0.57
# 526                  39.0                 106.0  0.99660  3.36       0.78
# 1202                  6.0                  12.0  0.99516  3.35       0.69
# 933                  13.0                  38.0  0.99748  3.48       0.65
#
#       alcohol  quality
# 524       9.5        5
# 837      11.7        7
# 1336      9.5        5
# 102       9.0        6
# 779       9.8        5
# 222       9.5        5
# 700      10.1        6
# 526      11.0        5
# 1202     11.7        8
# 933       9.8        5

# %%
df_raw.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
df_raw.shape
# Out:
# (1599, 12)

# %%
df_raw['wine_id']=[i+1 for i in range(len(df_raw))]

# %%
df_raw.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  wine_id
# 0      9.4        5        1
# 1      9.8        5        2
# 2      9.8        5        3
# 3      9.8        6        4
# 4      9.4        5        5

# %%
## Determine the Feature that will be focused on
pca_cols=df_raw.columns.tolist()
pca_cols=list(set(pca_cols)-set(['wine_id','quality']))

# %%
mod_info=data_pca_exploration(df_raw,pca_cols)
# Out:
# (1599, 11)

# %% [markdown]
# ## outliers detect

# %%
outlier_detect=IsolationForest(n_estimators=300,
    contamination=0.03,
    max_features=0.9)

mod_info.outlier_label(outlier_detect,normalize=False)
# Out:
# fitting anomaly
# done

# %%
mod_info.raw_data.head()
# Out:
#    total sulfur dioxide  citric acid  residual sugar  chlorides  \
# 0                  34.0         0.00             1.9      0.076
# 1                  67.0         0.00             2.6      0.098
# 2                  54.0         0.04             2.3      0.092
# 3                  60.0         0.56             1.9      0.075
# 4                  34.0         0.00             1.9      0.076
#
#    free sulfur dioxide    pH  sulphates  density  volatile acidity  \
# 0                 11.0  3.51       0.56   0.9978              0.70
# 1                 25.0  3.20       0.68   0.9968              0.88
# 2                 15.0  3.26       0.65   0.9970              0.76
# 3                 17.0  3.16       0.58   0.9980              0.28
# 4                 11.0  3.51       0.56   0.9978              0.70
#
#    fixed acidity  alcohol  outliers
# 0            7.4      9.4         1
# 1            7.8      9.8         1
# 2            7.8      9.8         1
# 3           11.2      9.8         1
# 4            7.4      9.4         1

# %% [markdown]
# ## plain PCA

# %%
mod_info.pca_features(normalize=False,outliers=True)

# %%
mod_info.raw_data_pca.head()
# Out:
#          p_1       p_2       p_3       p_4       p_5       p_6       p_7  \
# 0 -13.224905 -2.023900 -1.126821 -0.399233 -1.085389 -0.198018  0.031547
# 1  22.037724  4.408322 -0.310378 -0.199938 -0.557109 -0.301325  0.223874
# 2   7.162673 -2.501461 -0.581868 -0.219069 -0.552934 -0.205114  0.136190
# 3  13.430063 -1.951122  2.634040 -1.574059 -0.063806  0.089092 -0.218923
# 4 -13.224905 -2.023900 -1.126821 -0.399233 -1.085389 -0.198018  0.031547
#
#         p_8       p_9      p_10      p_11
# 0 -0.147051  0.006047  0.008585  0.000262
# 1  0.143165 -0.089312 -0.015483  0.000243
# 2  0.058480 -0.084793 -0.005749  0.000346
# 3 -0.062244  0.006281  0.004586 -0.000747
# 4 -0.147051  0.006047  0.008585  0.000262

# %%
mod_info.pca_component_contribution
# Out:
#     Variance Contribution  Cumulative Variance Contribution
# 0            9.465770e-01                          0.946577
# 1            4.836830e-02                          0.994945
# 2            2.589172e-03                          0.997534
# 3            1.518968e-03                          0.999053
# 4            8.735540e-04                          0.999927
# 5            3.456072e-05                          0.999962
# 6            1.936276e-05                          0.999981
# 7            9.472781e-06                          0.999990
# 8            8.413766e-06                          0.999999
# 9            1.214728e-06                          1.000000
# 10           4.687628e-10                          1.000000

# %%
mod_info.raw_data[pca_cols].std().sort_values(ascending=False)
# Out:
# total sulfur dioxide    32.895324
# free sulfur dioxide     10.460157
# fixed acidity            1.741096
# residual sugar           1.409928
# alcohol                  1.065668
# citric acid              0.194801
# volatile acidity         0.179060
# sulphates                0.169507
# pH                       0.154386
# chlorides                0.047065
# density                  0.001887
# dtype: float64

# %%
mod_info.df_features_quality
# Out:
#                        quality
# total sulfur dioxide  0.999936
# free sulfur dioxide   0.999521
# fixed acidity         0.024674
# alcohol               0.015892
# residual sugar        0.014099
# pH                    0.003283
# citric acid           0.003040
# volatile acidity      0.002046
# sulphates             0.000658
# chlorides             0.000245
# density               0.000025

# %%
mod_info.principle_infos
# Out:
#                            p_1       p_2       p_3       p_4       p_5  \
# total sulfur dioxide  0.975678 -0.218917 -0.001527 -0.003980  0.010323
# citric acid           0.000171 -0.003035  0.073708 -0.009832  0.041482
# residual sugar        0.008649  0.011135  0.280914  0.943178 -0.176627
# chlorides             0.000064 -0.000237  0.002946 -0.000645 -0.009480
# free sulfur dioxide   0.218857  0.975266  0.020897 -0.021189 -0.007868
# pH                   -0.000268  0.003272 -0.058631  0.020578  0.012622
# sulphates             0.000223  0.000619  0.017525 -0.007199  0.023585
# density               0.000004 -0.000025  0.000776  0.000055 -0.000834
# volatile acidity      0.000384 -0.002010 -0.025132  0.007274 -0.041157
# fixed acidity        -0.006132 -0.023899  0.953136 -0.265092  0.098148
# alcohol              -0.006358  0.014564 -0.048599  0.197614  0.977129
#
#                            p_6       p_7       p_8       p_9      p_10  \
# total sulfur dioxide -0.000614 -0.000230 -0.001212 -0.000657  0.000260
# citric acid           0.504044 -0.205508  0.327123  0.760466 -0.105489
# residual sugar        0.005766  0.002495 -0.004134 -0.006931 -0.001486
# chlorides             0.057016  0.113948  0.132518  0.072197  0.980249
# free sulfur dioxide  -0.001060 -0.000093  0.002574  0.001499 -0.000318
# pH                   -0.142002 -0.010261 -0.859197  0.478788  0.090645
# sulphates             0.488427  0.853721 -0.132919 -0.053568 -0.105567
# density              -0.000467  0.001600 -0.004108  0.002839  0.002033
# volatile acidity     -0.689242  0.464366  0.338841  0.428632 -0.091587
# fixed acidity        -0.079312  0.011142 -0.064907 -0.016206  0.011189
# alcohol              -0.050825  0.008250  0.021779 -0.018024  0.010112
#
#                           p_11   quality
# total sulfur dioxide -0.000003  0.999936
# citric acid          -0.000058  0.003040
# residual sugar       -0.000413  0.014099
# chlorides            -0.001819  0.000245
# free sulfur dioxide   0.000009  0.999521
# pH                   -0.005068  0.003283
# sulphates            -0.001311  0.000658
# density               0.999983  0.000025
# volatile acidity     -0.000719  0.002046
# fixed acidity        -0.000942  0.024674
# alcohol               0.000925  0.015892

# %%
mod_info.get_best_quality_feature(correlation_benchmark=0.85)

# %%
mod_info.Best_Features_Quality
# Out:
# ['total sulfur dioxide', 'free sulfur dioxide']

# %%
mod_info.corr_mat
# Out:
#                       total sulfur dioxide  free sulfur dioxide
# total sulfur dioxide              1.000000             0.445778
# free sulfur dioxide               0.445778             1.000000

# %%
mod_info.coc_plot(rad=1.5,annot=True)

# %% [markdown]
# ## plain PCA without outliers

# %%
mod_info.pca_features(normalize=False,outliers=Fal)

# %% [markdown]
# ## Standardized PCA
#
# Standardized without outliers

# %%
mod_info.pca_features(normalize=True,outliers=True)

# %%
mod_info.normalize_data[pca_cols].std().sort_values(ascending=False)
# Out:
# chlorides               1.408888
# residual sugar          1.262645
# sulphates               1.080980
# density                 1.067658
# free sulfur dioxide     1.062687
# total sulfur dioxide    1.055680
# pH                      1.045951
# fixed acidity           1.038061
# alcohol                 1.035984
# citric acid             1.026202
# volatile acidity        1.003070
# dtype: float64

# %%
mod_info.df_features_quality
# Out:
#                        quality
# total sulfur dioxide  0.526121
# free sulfur dioxide   0.500415
# fixed acidity         0.484737
# chlorides             0.475621
# citric acid           0.458085
# residual sugar        0.425828
# pH                    0.421838
# density               0.413203
# volatile acidity      0.321887
# alcohol               0.308509
# sulphates             0.270098

# %%
mod_info.principle_infos
# Out:
#                            p_1       p_2       p_3       p_4       p_5  \
# total sulfur dioxide  0.054819  0.523257 -0.163736  0.225619 -0.350667
# citric acid           0.404313 -0.215344 -0.174782  0.216532 -0.072132
# residual sugar        0.209759  0.370582 -0.447745 -0.023110  0.715511
# chlorides             0.408091  0.244288  0.727064  0.114566  0.244440
# free sulfur dioxide  -0.006032  0.500379 -0.179749  0.337826 -0.291146
# pH                   -0.406324  0.113348  0.053384  0.055376  0.234673
# sulphates             0.267828 -0.034939  0.220031  0.428319  0.059269
# density               0.396463  0.116420 -0.150827 -0.411025  0.001115
# volatile acidity     -0.169006  0.273949  0.194447 -0.404691  0.117036
# fixed acidity         0.424843 -0.233405 -0.213298 -0.165037 -0.127521
# alcohol              -0.141009 -0.274398 -0.154652  0.477437  0.356106
#
#                            p_6       p_7       p_8       p_9      p_10  \
# total sulfur dioxide -0.095742  0.132270  0.053547  0.600706 -0.356700
# citric acid          -0.150001 -0.102515 -0.292079  0.399639  0.651061
# residual sugar       -0.065767 -0.111599  0.247573 -0.022439  0.068418
# chlorides            -0.300327 -0.116207 -0.213189 -0.043421 -0.140450
# free sulfur dioxide  -0.002843  0.048757 -0.266414 -0.620721  0.239071
# pH                    0.416058 -0.256098 -0.599124  0.210352  0.009064
# sulphates             0.712554  0.249729  0.328521  0.016733  0.093690
# density               0.399035 -0.034506 -0.330660  0.000791 -0.237860
# volatile acidity     -0.019646  0.711233 -0.073277  0.128883  0.391005
# fixed acidity        -0.015841  0.313024 -0.250357 -0.174856 -0.241796
# alcohol              -0.181934  0.459001 -0.299741 -0.006502 -0.300891
#
#                           p_11   quality
# total sulfur dioxide  0.070026  0.526121
# citric acid          -0.074887  0.458085
# residual sugar        0.149827  0.425828
# chlorides             0.039059  0.475621
# free sulfur dioxide  -0.050703  0.500415
# pH                    0.345102  0.421838
# sulphates             0.067687  0.270098
# density              -0.557887  0.413203
# volatile acidity      0.001750  0.321887
# fixed acidity         0.652750  0.484737
# alcohol              -0.319286  0.308509

# %%
# mod_info.get_best_quality_feature(correlation_benchmark=0.85)
mod_info.get_best_quality_feature(correlation_benchmark=0.85,top_benchmark=0.45)

# %%
mod_info.Best_Features_Quality
# Out:
# ['fixed acidity',
#  'total sulfur dioxide',
#  'citric acid',
#  'chlorides',
#  'free sulfur dioxide']

# %%
mod_info.corr_mat
# Out:
#                       total sulfur dioxide  free sulfur dioxide  \
# total sulfur dioxide              1.000000             0.445778
# free sulfur dioxide               0.445778             1.000000
# fixed acidity                     0.012810             0.023653
# chlorides                         0.002247             0.000031
# citric acid                       0.001263             0.003718
#
#                       fixed acidity  chlorides  citric acid
# total sulfur dioxide       0.012810   0.002247     0.001263
# free sulfur dioxide        0.023653   0.000031     0.003718
# fixed acidity              1.000000   0.008781     0.451186
# chlorides                  0.008781   1.000000     0.041544
# citric acid                0.451186   0.041544     1.000000

# %%
mod_info.Best_Features_Quality
# Out:
# ['fixed acidity',
#  'total sulfur dioxide',
#  'citric acid',
#  'chlorides',
#  'free sulfur dioxide']

# %%
mod_info.corr_mat
# Out:
#                       total sulfur dioxide  free sulfur dioxide  \
# total sulfur dioxide              1.000000             0.445778
# free sulfur dioxide               0.445778             1.000000
# fixed acidity                     0.012810             0.023653
# chlorides                         0.002247             0.000031
# citric acid                       0.001263             0.003718
#
#                       fixed acidity  chlorides  citric acid
# total sulfur dioxide       0.012810   0.002247     0.001263
# free sulfur dioxide        0.023653   0.000031     0.003718
# fixed acidity              1.000000   0.008781     0.451186
# chlorides                  0.008781   1.000000     0.041544
# citric acid                0.451186   0.041544     1.000000

# %%
mod_info.coc_plot(rad=0.7,annot=True,top_quality=5)

# %% [markdown]
# ## Standardized PCA without outliers
#
# Standardized without outliers
